# %%
def add(x,y):
x=10
y=100
z=x+y
print("addition {} and {} is {}".format(x,y,z))
# Out:
#   Cell In[8], line 2
#     x=10
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
def mul(x,y):
    z=x*y
    print(z)

# %%
def mul(x,y):
    z=x*y
    print('z')

# %%
mul
# Out:
# <function __main__.mul(x, y)>

# %%
mul(14,37)
# Out:
# z

# %%
mul
# Out:
# <function __main__.mul(x, y)>

# %%
def mul(10,45):
    z=x*y
    print(z)
# Out:
#   Cell In[10], line 1
#     def mul(10,45):
#             ^
# SyntaxError: invalid syntax

# %%
mul
# Out:
# <function __main__.mul(x, y)>

# %%
def mul(x,y):
    z=x*y
    print(z)
    mul(10,23)

# %%
mul
# Out:
# <function __main__.mul(x, y)>

# %%
def mul(x,y):
    z=x*y
    print(z)
    mul(10,2)

# %%
mul
# Out:
# <function __main__.mul(x, y)>

# %%
def even_odd(no):
    if no%2==0:
        print('Even number')
    else:
        print('odd number')

# %%
even_odd(10)
# Out:
# Even number

# %%
even_odd(105)
# Out:
# odd number

# %%
def positive_negative(no):
    if no>0:
        print("positive number")
    else:
        print("negative number")

# %%
positive_negative(-1526)
# Out:
# negative number

# %%
positive_negative(15)
# Out:
# positive number

# %%
t=positive_negative(15)
# Out:
# positive number

# %%
t=positive_negative(15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 t=positive_negative(15)
#
# NameError: name 'positive_negative' is not defined

# %%
def bonuscal(sal):
    bonus=(sal/100)*5
    return bonus
